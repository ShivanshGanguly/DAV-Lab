# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivanshGanguly/DAV-Lab/blob/main/DAV_Lab_04_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("/content/student_performance_dataset.csv")
print("First 5 rows of dataset")
print(df.head())
# Out:
# First 5 rows of dataset
#   Student_ID  Gender  ...  Final_Exam_Score  Pass_Fail
# 0       S147    Male  ...                63       Pass
# 1       S136    Male  ...                50       Fail
# 2       S209  Female  ...                55       Fail
# 3       S458  Female  ...                65       Pass
# 4       S078  Female  ...                70       Pass
#
# [5 rows x 10 columns]

# %%
print("\nDataset info:")
print(df.info())
# Out:
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  708 non-null    object
#  1   Gender                      708 non-null    object
#  2   Study_Hours_per_Week        708 non-null    int64
#  3   Attendance_Rate             708 non-null    float64
#  4   Past_Exam_Scores            708 non-null    int64
#  5   Parental_Education_Level    708 non-null    object
#  6   Internet_Access_at_Home     708 non-null    object
#  7   Extracurricular_Activities  708 non-null    object
#  8   Final_Exam_Score            708 non-null    int64
#  9   Pass_Fail                   708 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 55.4+ KB
# None

# %%
print("\nMissing values before handling:")
print(df.isnull().sum())
# Out:
# Missing values before handling:
# Student_ID                    0
# Gender                        0
# Study_Hours_per_Week          0
# Attendance_Rate               0
# Past_Exam_Scores              0
# Parental_Education_Level      0
# Internet_Access_at_Home       0
# Extracurricular_Activities    0
# Final_Exam_Score              0
# Pass_Fail                     0
# dtype: int64

# %%
df.loc[0:5,"Study_Hours_per_Week"] = None
df.loc[10:15,"Attendance_Rate"] = None
df.loc[20:25,"Past_Exam_Score"] = None
df.loc[30:35,"Final_Exam_Score"] = None
print("\nMissing values after inserting sample Nulls:")
print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Missing values after inserting sample Nulls:
# Study_Hours_per_Week      6
# Attendance_Rate          12
# Final_Exam_Score         12
# Past_Exam_Score         708
# dtype: int64

# %%
df["Study_Hours_per_Week"].fillna(df["Study_Hours_per_Week"].mean())
# Out:
# 0      79.372680
# 1      79.372680
# 2      79.372680
# 3      79.372680
# 4      79.372680
#          ...
# 703    84.658761
# 704    60.278990
# 705    98.384969
# 706    96.148012
# 707    80.404392
# Name: Attendance_Rate, Length: 708, dtype: float64

# %%
df["Final_Exam_Score"] = df["Final_Exam_Score"].ffill()

# %%
df["Attendance_Rate"].fillna(df["Attendance_Rate"].median())
# Out:
# 0      79.372680
# 1      79.372680
# 2      79.372680
# 3      79.372680
# 4      79.372680
#          ...
# 703    84.658761
# 704    60.278990
# 705    98.384969
# 706    96.148012
# 707    80.404392
# Name: Attendance_Rate, Length: 708, dtype: float64

# %%
df["Final_Exam_Score"] = df["Final_Exam_Score"].fillna(df["Final_Exam_Score"].mean())
print("\nMissing values after imputation:")
print(df.isnull().sum())
# Out:
# Missing values after imputation:
# Student_ID                      0
# Gender                          0
# Study_Hours_per_Week            6
# Attendance_Rate                12
# Past_Exam_Scores                0
# Parental_Education_Level        0
# Internet_Access_at_Home         0
# Extracurricular_Activities      0
# Final_Exam_Score                0
# Pass_Fail                       0
# Past_Exam_Score               708
# dtype: int64

# %%
print("\nOne-Hot Encoded columns:")
print(df.columns.tolist())
# Out:
# One-Hot Encoded columns:
# ['Student_ID', 'Gender', 'Study_Hours_per_Week', 'Attendance_Rate', 'Past_Exam_Scores', 'Internet_Access_at_Home', 'Extracurricular_Activities', 'Final_Exam_Score', 'Pass_Fail', 'Past_Exam_Score', 'Parental_Education_Level_Bachelors', 'Parental_Education_Level_High School', 'Parental_Education_Level_Masters', 'Parental_Education_Level_PhD', 'Pass_Fail_Encoded', 'Gender_Encoded', 'Internet_Access_Encoded', 'Extraxurricular_Encoded']

# %%
le = LabelEncoder()
df["Pass_Fail_Encoded"] = le.fit_transform(df["Pass_Fail"])
print("\nEncoded Pass/Fail column:")
print(df[["Pass_Fail", "Pass_Fail_Encoded"]].head())
# Out:
# Encoded Pass/Fail column:
#   Pass_Fail  Pass_Fail_Encoded
# 0      Pass                  1
# 1      Fail                  0
# 2      Fail                  0
# 3      Pass                  1
# 4      Pass                  1

# %%
df["Gender_Encoded"] = le.fit_transform(df["Gender"])
df["Internet_Access_Encoded"] = le.fit_transform(df["Internet_Access_at_Home"])
df["Extraxurricular_Encoded"] = le.fit_transform(df["Extracurricular_Activities"])

# %%
df.to_csv("student_performance_cleaned.csv",index=False)
print("\nCleaned dataset saved as 'student_performance_cleaned.csv'")
# Out:
# Cleaned dataset saved as 'student_performance_cleaned.csv'
